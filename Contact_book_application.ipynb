# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka-garg04/AIML-bootcamp-projects/blob/main/Contact_book_application.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem Statement
# Create a simple contact book application to manage contacts.
# Requirements
# Display menu continuously until exit.
# User can:
# Add Contact
# Search Contact
# Delete Contact
# View All Contacts
# Exit
# Store contacts in a dictionary or list.
# Display appropriate messages for invalid operations.

# %%
contacts=[]
while True:
  print("Contact Book:")
  print("1. Add Contact")
  print("2. Search Contact")
  print("3. Delete Contact")
  print("4. View All Contacts")
  print("5. Exit")
  choice=int(input("Enter your choice:"))
  if choice==1:
    name=input("Enter name:")
    phone=int(input("Enter phone number:"))
    email=input("Enter email:")
    contacts.append({
        'name':name,
        'phone':phone,
        'email':email
    })
  elif choice==2:
    name=input("Enter name to search:")
    found=False
    for contact in contacts:
      if contact['name']==name:
        print("Name:",contact['name'])
        print("Phone:",contact['phone'])
        print("Email:",contact['email'])
        found=True
        break
      else:
        print("Contact not found")
  elif choice==3:
    name=input("Enter name to delete:")
    found=False
    for contact in contacts:
      if contact['name']==name:
        contacts.remove(contact)
        print("Contact deleted")
        found=True
        break
      else:
        print("Contact not found")
  elif choice==4:
    print("All contacts:")
    for contact in contacts:
      print("Name:",contact['name'])
      print("Phone:",contact['phone'])
      print("Email:",contact['email'])
  elif choice==5:
    print("Exiting...")
    break
  else:
    print("Invalid choice.")
# Out:
# Contact Book:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. View All Contacts
# 5. Exit
# Enter your choice:1
# Enter name:Anushka
# Enter phone number:9458071312
# Enter email:anushkagarg2004@gmail.com
# Contact Book:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. View All Contacts
# 5. Exit
# Enter your choice:1
# Enter name:Anshul
# Enter phone number:8307202190
# Enter email:anshulsharma@gmail.com
# Contact Book:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. View All Contacts
# 5. Exit
# Enter your choice:3
# Enter name to delete:Anshul
# Contact not found
# Contact deleted
# Contact Book:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. View All Contacts
# 5. Exit
# Enter your choice:4
# All contacts:
# Name: Anushka
# Phone: 9458071312
# Email: anushkagarg2004@gmail.com
# Contact Book:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. View All Contacts
# 5. Exit
# Enter your choice:5
# Exiting...
