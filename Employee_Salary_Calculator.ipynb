# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka-garg04/AIML-bootcamp-projects/blob/main/Employee_Salary_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
employees=[]
while True:
  name=input("Enter the employee's name (or 'exit' to stop) :")
  if lower(name)=='exit':
    break
  basic_salary=float(input("Enter the basic salary of the employee:"))
  hra=20*basic_salary/100
  da=10*basic_salary/100
  gross_salary=basic_salary+hra+da
  employees.append({
    'name':name,
    'Basic salary':basic_salary,
    'HRA':hra,
    'DA':da
    'Gross salary':gross_salary
  })
  for employee in employees:
    print("\n Employee details:")
    for key,value in employee:
      print(f"{key}:{value}")
